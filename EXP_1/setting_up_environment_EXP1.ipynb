# %% [markdown]
# <a href="https://colab.research.google.com/github/Aakashvelan/build-and-deploy/blob/main/EXP_1/setting_up_environment_EXP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AI23521 - BUILD AND DEPLOY FOR MACHINE LEARNING APPLICATION
#
# ## Experiment 1
#
# ### AIM
# To set up a fully functional Machine Learning development environment and perform data preprocessing operations such as handling missing values, encoding categorical variables, feature scaling, and splitting the dataset into training and testing sets.

# %% [markdown]
# ## ALGORITHM
#
# 1. Install the required libraries.
# 2. Import the necessary Python libraries.
# 3. Load the Titanic dataset.
# 4. Explore the dataset using `info()`, `describe()`, and `isnull().sum()`.
# 5. Handle missing values using suitable techniques.
# 6. Encode categorical variables using `LabelEncoder`.
# 7. Scale numerical features using `StandardScaler`.
# 8. Split the dataset into training and testing sets using `train_test_split()`.
# 9. Display the preprocessed training data.

# %%
# Install required libraries (Run only once)
# !pip install numpy pandas matplotlib seaborn scikit-learn

# %%
# Import Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %% [markdown]
# ## Load the Dataset
# The Titanic dataset is loaded using Seaborn.

# %%
# Load Dataset

df = sns.load_dataset('titanic')

print("First Five Rows")
display(df.head())
# Out:
# First Five Rows
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## Data Exploration
# The dataset is explored to understand its structure, summary statistics, and missing values.

# %%
# Dataset Information

print("Dataset Information")
df.info()

print("\nStatistical Summary")
display(df.describe())

print("\nMissing Values")
print(df.isnull().sum())
# Out:
# Dataset Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
#
# Statistical Summary
# ...

# %% [markdown]
# ## Handling Missing Values
# Missing values in the **age** column are replaced with the median value, **embark_town** with the mode value, and the **deck** column is removed because it contains many missing values.

# %%
# Handle Missing Values

df['age'].fillna(df['age'].median(), inplace=True)
df['embark_town'].fillna(df['embark_town'].mode()[0], inplace=True)

# Drop deck column
df.drop(columns=['deck'], inplace=True)

print("Missing Values After Preprocessing")
print(df.isnull().sum())
# Out:
# Missing Values After Preprocessing
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64
# /tmp/ipykernel_654/2902680023.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(), inplace=True)
# ...

# %% [markdown]
# ## Encoding Categorical Variables
# The categorical columns **sex** and **embark_town** are converted into numerical values using Label Encoding.

# %%
# Encode Categorical Variables

le = LabelEncoder()

df['sex'] = le.fit_transform(df['sex'])
df['embark_town'] = le.fit_transform(df['embark_town'])

# Drop unnecessary columns
df.drop(columns=['embarked', 'class', 'who', 'alive',
                 'adult_male', 'alone'], inplace=True)

display(df.head())
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embark_town
# 0         0       3    1  22.0      1      0   7.2500            2
# 1         1       1    0  38.0      1      0  71.2833            0
# 2         1       3    0  26.0      0      0   7.9250            2
# 3         1       1    0  35.0      1      0  53.1000            2
# 4         0       3    1  35.0      0      0   8.0500            2

# %% [markdown]
# ## Feature Scaling
# The numerical features **age** and **fare** are standardized using StandardScaler.

# %%
# Feature Scaling

scaler = StandardScaler()

numerical_cols = ['age', 'fare']

df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

display(df.head())
# Out:
#    survived  pclass  sex       age  sibsp  parch      fare  embark_town
# 0         0       3    1 -0.565736      1      0 -0.502445            2
# 1         1       1    0  0.663861      1      0  0.786845            0
# 2         1       3    0 -0.258337      0      0 -0.488854            2
# 3         1       1    0  0.433312      1      0  0.420730            2
# 4         0       3    1  0.433312      0      0 -0.486337            2

# %% [markdown]
# ## Splitting the Dataset
# The dataset is divided into training and testing datasets using an 80:20 ratio.

# %%
# Split Dataset

X = df.drop('survived', axis=1)
y = df['survived']

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training Data Shape:", X_train.shape)
print("Testing Data Shape :", X_test.shape)
# Out:
# Training Data Shape: (712, 7)
# Testing Data Shape : (179, 7)

# %% [markdown]
# ## Display the Preprocessed Training Data
# The first five rows of the preprocessed training dataset are displayed.

# %%
# Display Training Data

display(X_train.head())
# Out:
#      pclass  sex       age  sibsp  parch      fare  embark_town
# 331       1    1  1.240235      0      0 -0.074583            2
# 733       2    1 -0.488887      0      0 -0.386671            2
# 382       3    1  0.202762      0      0 -0.488854            2
# 704       3    1 -0.258337      1      0 -0.490280            2
# 813       3    0 -1.795334      4      2 -0.018709            2

# %% [markdown]
# # RESULT
#
# The machine learning environment was successfully set up. The Titanic dataset was loaded, explored, preprocessed by handling missing values, encoding categorical variables, scaling numerical features, and splitting the dataset into training and testing sets successfully.
